# %%
pip install matplotlib
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/165.0 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/165.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 165.0/165.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.0 MB 3.9 MB/s eta 0:00:02
#     --------------------------------------- 0.2/8.0 MB 3.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.0 MB 2.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/8.0 MB 2.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.4/8.0 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/8.0 MB 1.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/8.0 MB 1.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/8.0 MB 1.9 MB/s eta 0:00:04
# ...

# %%
import matplotlib.pyplot as plt 

# Data contoh 
hari = ['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9', 'H10']
jumlah_penjualan = [50, 30, 70, 45, 90, 55, 65, 75, 35, 80]

# grafiknya
plt.figure(figsize=(8, 4))
plt.plot(hari, jumlah_penjualan, marker= '*', color='g', linestyle='-')
plt.title('Line Chart Penjualan Per Hari')
plt.xlabel('hari')
plt.ylabel('Jumlah Penjualan')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt 

# Data contoh 
tahun = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7']
jumlah_penghasilan = [15.000000, 30.0000000, 70.000000, 45.000000, 90.000000, 55.000000, 65.000000]

# grafiknya
plt.figure(figsize=(10, 5))
plt.plot(tahun, jumlah_penghasilan, marker= '*', color='g', linestyle='-')
plt.title('Line Chart Penghasilan Per Tahun')
plt.xlabel('tahun')
plt.ylabel('Jumlah Penghasilan')
plt.grid(True)
plt.show()

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt 

# Data contoh 
hari = ['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8']
jumlah_penghasilan = [50.000, 100.000, 90.000, 75.000, 400.000, 300.000, 120.000, 150.000]

# grafiknya
plt.figure(figsize=(16, 6))
plt.plot(hari, jumlah_penghasilan, marker= '*', color='g', linestyle='-')
plt.title('Line Chart Penghasilan Per Hari')
plt.xlabel('hari')
plt.ylabel('Jumlah Penghasilan')
plt.grid(True)
plt.show()

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt 

# Data contoh 
semester = ['Smt1', 'Smt2', 'Smt3', 'Smt', 'Smt5', 'Smt6', 'Smt7', 'Smt8']
nilai_ipk = [3.04, 3.31, 3.00, 3.54, 3.33, 3.99, 4.00, 4.00]

# grafiknya
plt.figure(figsize=(16, 6))
plt.plot(semester, nilai_ipk , marker= '*', color='g', linestyle='-')
plt.title('Line Chart Nilai Ipk Per Semester')
plt.xlabel('semester')
plt.ylabel('nilai ipk')
plt.grid(True)
plt.show()
